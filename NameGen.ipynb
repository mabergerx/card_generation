# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import LSTM
from keras.layers import TimeDistributed
from keras.layers import Activation
from keras.callbacks import ModelCheckpoint
from keras.utils import np_utils
from keras.models import load_model
import pickle

# %%
def generate_text(model, length, ixtochars):
    
    hele_tekst = []
    
    ix = [np.random.randint(NUMBER_FEATURES)]
    y_char = [ixtochars[ix[-1]]]
    X = np.zeros((1, length, NUMBER_FEATURES))
    for i in range(length):
        X[0, i, :][ix[-1]] = 1
        print(ixtochars[ix[-1]], end="")
        ix = np.argmax(model.predict(X[:, :i+1, :])[0], 1)
        hele_tekst.append(ixtochars[ix[-1]])
    return hele_tekst

# %%
nametext_model = load_model("models/nametext_2200epochs.h5")
with open('char_mappings_nametext/ixtochar.pkl', 'rb') as handle:
    nametext_ix_to_char = pickle.load(handle)

# %%
NUMBER_FEATURES = len(nametext_ix_to_char)
NUMBER_FEATURES
# Out:
# 65

# %%
for i in range(100):
    generate_text(nametext_model, 25, nametext_ix_to_char)
    print('\n----\n')
# Out:
# zan AuctioneerGhoro GodMi
# ----
#
# DemonsShadow BorserBaron
# ----
#
# 4 ChampionAmastingerAncie
# ----
#
# Bloodmage Thalnice Roodeu
# ----
#
# ureFearsome DoogerVorkon
# ----
#
# s HandDefileDemeten Irort
# ----
#
# X CombanantScaled GiettBo
# ----
#
# ManastormMistressOlecer S
# ----
#
# ce DarknessEntentar Sotec
# ----
#
# g SwordsDark CunthpperCot
# ----
#
# King DredTar Lord Pustor
# ----
#
# ureFearsome DoogerVorkon
# ----
#
# zan AuctioneerGhoro GodMi
# ----
#
# er the Coliseum Stalentra
# ----
#
#  CrawlerGrimestaceer tea
# ----
#
# blic DefenderPura ChaartM
# ----
#
# !fire ConsurionGobold Aut
# ----
#
# y ChickenAnimat om Worcer
# ----
#
# -BarberGolakka Bage Black
# ----
#
# Zealot TagantBlackwan Gne
# ----
#
# ArcanistEvil Hesperton Pi
# ----
#
# LoathebLotus Agsenstine E
# ----
#
# GuardianBig Gammore Raie
# ----
#
# ve ArcherBuccane Ditcieer
# ----
#
#  CrawlerGrimestaceer tea
# ----
#
# ManastormMistressOlecer S
# ----
#
# HallucinationHamon Choman
# ----
#
# 3 ChampionAmaman AstinyGr
# ----
#
# Tortollan ForagoNoctSpide
# ----
#
# ManastormMistressOlecer S
# ----
#
# y ChickenAnimat om Worcer
# ----
#
# HallucinationHamon Choman
# ----
#
# GuardianBig Gammore Raie
# ----
#
# Elise StarseekerSeratere
# ----
#
# OozeAlexstraszar Crago Al
# ----
#
# WardenMurloc KnigolKorerL
# ----
#
# WardenMurloc KnigolKorerL
# ----
#
# ManastormMistressOlecer S
# ----
#
# s HandDefileDemeten Irort
# ----
#
# quisitorVoidwalkerkhald S
# ----
#
# 's ParrotCatheden the Sab
# ----
#
# GuardianBig Gammore Raie
# ----
#
# Your PartyHoly Serkustor
# ----
#
# Bloodmage Thalnice Roodeu
# ----
#
# kerToshleyTraded Dedon Ka
# ----
#
# Jade ChieftainKraniue Wot
# ----
#
# Jade ChieftainKraniue Wot
# ----
#
# r TotemicTwilight Prowe S
# ----
#
# r TotemicTwilight Prowe S
# ----
#
# Jade ChieftainKraniue Wot
# ----
#
# ng ShoutConfuseron Hunuer
# ----
#
# r TotemicTwilight Prowe S
# ----
#
# ureFearsome DoogerVorkon
# ----
#
# pionBloodlustBrade Cromra
# ----
#
# OozeAlexstraszar Crago Al
# ----
#
# Jade ChieftainKraniue Wot
# ----
#
# ler's RunSoulfie Champhat
# ----
#
# 2 CombatantScalen Geemate
# ----
#
# Zealot TagantBlackwan Gne
# ----
#
# 3 ChampionAmaman AstinyGr
# ----
#
# pionBloodlustBrade Cromra
# ----
#
# 7 ShadeAnimated Fonsaiper
# ----
#
# wordsmithMechwand Pridone
# ----
#
# LoathebLotus Agsenstine E
# ----
#
# ler's RunSoulfie Champhat
# ----
#
# Tortollan ForagoNoctSpide
# ----
#
# y ChickenAnimat om Worcer
# ----
#
# Nightscale MatresMark Pit
# ----
#
# !fire ConsurionGobold Aut
# ----
#
# 7 ShadeAnimated Fonsaiper
# ----
#
# Jade ChieftainKraniue Wot
# ----
#
# kerToshleyTraded Dedon Ka
# ----
#
# g SwordsDark CunthpperCot
# ----
#
# QuartermasterQuath t e Ta
# ----
#
# , Tyrant of the Wold:eThi
# ----
#
# 's ParrotCatheden the Sab
# ----
#
# OozeAlexstraszar Crago Al
# ----
#
# Untiontion MatianMunterin
# ----
#
# Bloodmage Thalnice Roodeu
# ----
#
# Untiontion MatianMunterin
# ----
#
# ureFearsome DoogerVorkon
# ----
#
# 1r TotemicTwilight Prome
# ----
#
# ce DarknessEntentar Sotec
# ----
#
#  CrawlerGrimestaceer tea
# ----
#
# PortalKara KazhazuTabage
# ----
#
# Untiontion MatianMunterin
# ----
#
# PortalKara KazhazuTabage
# ----
#
# . SpellstoneLesser Dithri
# ----
#
# s HandDefileDemeten Irort
# ----
#
# FlamecannonFlara KathArca
# ----
#
# r TotemicTwilight Prowe S
# ----
#
#  CrawlerGrimestaceer tea
# ----
#
# wordsmithMechwand Pridone
# ----
#
# Zealot TagantBlackwan Gne
# ----
#
# the Flying StarmerShivefi
# ----
#
# 's ParrotCatheden the Sab
# ----
#
# Untiontion MatianMunterin
# ----
#
# 00Blood-Queen Lord ofimor
# ----
#
# ce DarknessEntentar Sotec
# ----
#
# !fire ConsurionGobold Aut
# ----
