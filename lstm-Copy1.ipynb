# %%
api_key = "hh8DW29tdDmshbghN71NJPI0jgFzp1Ay5MzjsniIz9a8Piq7xp"

# %% [markdown]
# ### Making the API request for all cards

# %%
import requests
headers = {'X-Mashape-Key': api_key}

# %%
# cardname = "Leeroy"

# %%
# endpoint_one_card = f"https://omgvamp-hearthstone-v1.p.mashape.com/cards/search/{cardname}"
# endpoint_allcards = "https://omgvamp-hearthstone-v1.p.mashape.com/cards"

def get_cards_by_type(card_type, collectible=1, cost=None, durability=None, health=None, key=api_key):
    endpoint_by_type = f'https://omgvamp-hearthstone-v1.p.mashape.com/cards/types/{card_type}'
    payload = {'collectible': collectible, 'cost': cost, 'durability': durability, 'health': health}
    r = requests.get(endpoint_by_type, params=payload, headers=headers)
    return r.json()

# %%
# r = requests.get(endpoint_allcards, headers=headers)

# %%
# r.json()

# %%
import json
# with open('hs_data.json', 'w') as outfile:
#     json.dump(r.json(), outfile)

# %% [markdown]
# ### Using the offline JSON

# %%
import pandas as pd

# %%
# Reading the json as a dict
with open('hs_data.json') as json_data:
    data = json.load(json_data)

# %%
everything = [single_card for cardset in data.values() for single_card in cardset]

# %%
collectibles = [single_card for single_card in everything 
                if 'collectible' in single_card 
                and single_card['collectible']]

# %%
non_heroes = [single_card for single_card in collectibles
              if single_card['type'] != 'Hero']

# %%
all_types = set([card['type'] for card in non_heroes])
all_types
# Out:
# {'Minion', 'Spell', 'Weapon'}

# %% [markdown]
# ### Otherwise, first separate the cards by type. We can make API calls for that.

# %%
collectible_spells = get_cards_by_type('Spell')
collectible_weapons = get_cards_by_type('Weapon')
collectible_minions = get_cards_by_type('Minion')

# %%
minions = collectible_minions
weapons = collectible_weapons
spells = collectible_spells

# %%
# for cardtype, collection in zip(['minions', 'spells', 'weapons'], [collectible_minions, collectible_spells, collectible_weapons]):
#     with open(f'{cardtype}.json', 'w') as outfile:
#         json.dump(collection, outfile)

# %%
# Reading the json as a dict
with open('data/minions.json') as json_data:
    minions = json.load(json_data)
    
with open('data/spells.json') as json_data:
    spells = json.load(json_data)
    
with open('data/weapons.json') as json_data:
    weapons = json.load(json_data)

# %% [markdown]
# ### Let's now separate the titles, flavors, texts, mechanics, costs and stats.
# #### Each card type has different attributes and design logic behind them, so we want to make educated splits. Moreover, not all fields are of interest for us for now.

# %%
spell_attributes = {"name", "cardId", "cost", "img", "playerClass", "rarity", "text", "flavor", "mechanics"}
# spell_optional_attributes = {}

minion_attributes = {"name", "cardId", "cost", "health", "attack", "img", "playerClass", "rarity", "text", "flavor", "mechanics"}
# minion_optional_attributes = {}

weapon_attributes = {"name", "cardId", "cost", "durability", "attack", "img", "playerClass", "rarity", "text", "flavor", "mechanics"}
# weapon_attributes = {}

# %% [markdown]
# ### For this first generation example we shall funnel all the cards to the above attributes to normalize the data.

# %%
def normalize_card(card, attrs):
    
    concise = {a: card[a] if a in card else None for a in attrs}
    
    return concise

# %%
spells_concise = [normalize_card(spell_card, spell_attributes) for spell_card in spells]
minions_concise = [normalize_card(minion_card, minion_attributes) for minion_card in minions]
weapons_concise = [normalize_card(weapon_card, weapon_attributes) for weapon_card in weapons]

# %%
weapons_concise[:2]
# Out:
# [{'attack': 1,
#   'cardId': 'LOOT_222',
#   'cost': 1,
#   'durability': 3,
#   'flavor': 'Once called Cahn’delar, Shortbow of the Ancient Whisker.',
#   'img': 'http://media.services.zam.com/v1/media/byName/hs/cards/enus/LOOT_222.png',
#   'mechanics': None,
#   'name': 'Candleshot',
#   'playerClass': 'Hunter',
#   'rarity': 'Common',
#   'text': 'Your hero is <b>Immune</b> while attacking.'},
#  {'attack': 2,
#   'cardId': 'LOE_118',
#   'cost': 1,
#   'durability': 3,
#   'flavor': 'The Curse is that you have to listen to "MMMBop" on repeat.',
#   'img': 'http://media.services.zam.com/v1/media/byName/hs/cards/enus/LOE_118.png',
#   'mechanics': None,
#   'name': 'Cursed Blade',
#   'playerClass': 'Warrior',
#   'rarity': 'Rare',
#   'text': 'Double all damage dealt to your hero.'}]

# %%
# titles = [(card['name'], card['cardId']) for card in non_heroes]
# flavors = [(card['flavor'], card['cardId']) for card in non_heroes]
# texts = [(card['text'], card['cardId']) for card in non_heroes]
# mechanics = [(card['mechanics'], card['cardId']) if 'mechanics' in card else None for card in non_heroes]
# costs = [(card['cost'], card['cardId']) for card in non_heroes]
# stats = [(card['name'], card['cardId']) for card in non_heroes]

# %% [markdown]
# ### The data is now quite ready to be modelled! We can now access the needed fields directly from the correpsonding cardtype set.

# %% [markdown]
# ## A small LSTM

# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import LSTM
from keras.layers import TimeDistributed
from keras.layers import Activation
from keras.callbacks import ModelCheckpoint
from keras.utils import np_utils
from keras.models import load_model

# %% [markdown]
# ### Let's get all the card texts.

# %%
def get_all_flavortexts():
    
    weapon_flavors = [card['flavor'] for card in weapons]
    minion_flavors = [card['flavor'] for card in minions]
    spell_flavors = [card['flavor'] for card in spells if 'flavor' in card]
    
    return weapon_flavors + minion_flavors + spell_flavors

# %%
def get_all_cardtexts():
    
    weapon_texts = [card['text'] for card in weapons if 'text' in card]
    minion_texts = [card['text'] for card in minions if 'text' in card]
    spell_texts = [card['text'] for card in spells if 'flavor' in card]
    
    return weapon_texts + minion_texts + spell_texts

# %%
# all_flavors = get_all_flavortexts()
all_texts = get_all_cardtexts()

# %% [markdown]
# ### Our average sequence length is 67.8 characters. This is handy to know for the LSTM sequence length parameter. Let's round it down for sake of memorability.

# %%
average_sequence_length = np.mean([len(list(text)) for text in all_texts])
average_sequence_length
# Out:
# 56.821935483870966

# %%
SEQUENCE_LENGTH = 57

# %% [markdown]
# ### Our generative model is a character based one, so our input data is a huge list of characters.

# %%
all_text_chars = [ch for one_sentence in all_texts for ch in list(one_sentence)]

# %%
all_text_unique_chars = list(set(all_text_chars))
all_text_unique_chars.sort()

# %% [markdown]
# ### We see that there are a lot of unnecessary or unwished characters in the model. We could clean up the model by moderating the char list but for now we let it like this.

# %%
print(f'Data length: {len(all_text_chars)} characters')
print(f'Vocabulary size: {len(all_text_unique_chars)} characters')
# Out:
# Data length: 88074 characters
# Vocabulary size: 83 characters

# %% [markdown]
# ### The unique characters are the features for our model. Let's numerify them to make them ML ready.

# %%
import pickle

# %%
ix_to_char = {ix:char for ix, char in enumerate(all_text_unique_chars)}
char_to_ix = {char:ix for ix, char in enumerate(all_text_unique_chars)}

# %%
with open('char_mappings_cardtext/ixtochar.pkl', 'wb') as handle:
    pickle.dump(ix_to_char, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
with open('char_mappings_cardtext/chartoix.pkl', 'wb') as handle:
    pickle.dump(char_to_ix, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ### LSTM expects input of the shape (batch_size, length_of_sequence, number_features)
# #### batch_size: amount of sequences which are fed into the network at one time, just as in a regular feedforward neural network
# #### length_of_sequence: the amount of "neural networks", the memory or the amount of steps the network looks at at each step. In our example, we want to predict a character given 65 previous characters.
# #### number_features: the length of one featurized element. In the case of images it could be padded standardized vectors of pixels. In case of text it is the length of our vocab, because our input is going to be represented by every char in our vocabulary.

# %%
NUMBER_FEATURES = len(all_text_unique_chars)

# %%
X = np.zeros((int(len(all_text_chars)/SEQUENCE_LENGTH), SEQUENCE_LENGTH, NUMBER_FEATURES))
y = np.zeros((int(len(all_text_chars)/SEQUENCE_LENGTH), SEQUENCE_LENGTH, NUMBER_FEATURES))

# %%
len(all_text_chars)
# Out:
# 88074

# %%
for i in range(0, int(len(all_text_chars)/SEQUENCE_LENGTH)):
    X_sequence = all_text_chars[i*SEQUENCE_LENGTH:(i+1)*SEQUENCE_LENGTH]  #Get next sequence of length 57 as input.
    X_sequence_ix = [char_to_ix[value] for value in X_sequence]  # Convert the above sequence to the integer mapping.
    # TODO: make this one hot encoding differently: Keras or sklearn or something.
    input_sequence = np.zeros((SEQUENCE_LENGTH, NUMBER_FEATURES))  # Create a skeleton for the input sequence: we create a 2d numpy matrix which has a feature array of 94 
                                                                   # long for each of the 57 characters in sequence. This way we basically one hot encode our sequences. 
    for j in range(SEQUENCE_LENGTH):  # The one hot encoding process: we replace a zero with a one on a position in the input sequence which corresponds with the index of a character in our converted array!
        input_sequence[j][X_sequence_ix[j]] = 1.
    X[i] = input_sequence
    
    #Same for y!
    y_sequence = all_text_chars[i*SEQUENCE_LENGTH+1:(i+1)*SEQUENCE_LENGTH+1]
    y_sequence_ix = [char_to_ix[value] for value in y_sequence]
    target_sequence = np.zeros((SEQUENCE_LENGTH, NUMBER_FEATURES))
    for j in range(SEQUENCE_LENGTH):
        target_sequence[j][y_sequence_ix[j]] = 1.
    y[i] = target_sequence

# %%
# # prepare the dataset of input to output pairs encoded as integers
# seq_length = 100
# dataX = []
# dataY = []
# n_chars = len(all_flavor_chars)
# for i in range(0, n_chars - SEQUENCE_LENGTH, 1):
#     seq_in = all_flavor_chars[i:i + SEQUENCE_LENGTH]
#     seq_out = all_flavor_chars[i + SEQUENCE_LENGTH]
#     dataX.append([char_to_ix[char] for char in seq_in])
#     dataY.append(char_to_ix[seq_out])
# n_patterns = len(dataX)
# print("Total Patterns: ", n_patterns)

# %%
# X = np.reshape(dataX, (n_patterns, SEQUENCE_LENGTH, 1))

# %%
# # normalize
# X = X / float(len(all_flavor_unique_chars))
# # one hot encode the output variable
# y = np_utils.to_categorical(dataY)

# %%
HIDDEN_DIM = 500
LAYER_NUM = 3

# %%
model = Sequential()
model.add(LSTM(HIDDEN_DIM, input_shape=(None, NUMBER_FEATURES), return_sequences=True))
for i in range(LAYER_NUM - 1):
    model.add(LSTM(HIDDEN_DIM, return_sequences=True))
    model.add(Dropout(0.25))
model.add(TimeDistributed(Dense(NUMBER_FEATURES)))
model.add(Activation('softmax'))
model.compile(loss="categorical_crossentropy", optimizer="rmsprop")
# Out:
# WARNING:tensorflow:From /home/datalab/anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:1247: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From /home/datalab/anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:1213: calling reduce_max (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead
# WARNING:tensorflow:From /home/datalab/anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:1349: calling reduce_mean (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead

# %%
def generate_text(model, length, ixtochars=ix_to_char):
    
    hele_tekst = []
    
    ix = [np.random.randint(NUMBER_FEATURES)]
    y_char = [ixtochars[ix[-1]]]
    X = np.zeros((1, length, NUMBER_FEATURES))
    for i in range(length):
        X[0, i, :][ix[-1]] = 1
        print(ixtochars[ix[-1]], end="")
        ix = np.argmax(model.predict(X[:, :i+1, :])[0], 1)
        hele_tekst.append(ixtochars[ix[-1]])
    return hele_tekst

# %%
nb_epoch = 0
BATCH_SIZE = 50
GENERATE_LENGTH = 70
while True:
    print('\n')
    model.fit(X, y, batch_size=BATCH_SIZE, verbose=1, nb_epoch=1)
    nb_epoch += 1
    generate_text(model, GENERATE_LENGTH)
    if nb_epoch % 10 == 0:
        model.save_weights('cardtext_cps/checkpoint_{}_epoch_{}.hdf5'.format(HIDDEN_DIM, nb_epoch))
# Out:
# Epoch 1/1
# /home/datalab/anaconda3/lib/python3.6/site-packages/keras/models.py:939: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   warnings.warn('The `nb_epoch` argument in `fit` '
# 1545/1545 [==============================] - 5s 3ms/step - loss: 2.8720
# moo  oo  ann  an  an  an  ao  aa  aa  aa  aa  aa  aa  aa  aa  aa  aa
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 2.5744
# Oe ee a aaa aaa aaa aaa aaa aaa aaa aaa aaa aaa aaa aaa aaa aaa aaa aa
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 2.2664
# 8/b> aatt  aadd or oor our oor oor oor oor oor oor oor oor oor oor oor
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 1.9901
# -//b> <b>Battlecry:</b> If your here a minion to your hand a mangon to
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 1.7374
# voer your opponent thas test and minion to your hend.<b>Battlecry:</b>
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 1.5319
# 5//b <b>Battlecry:</b> Give a random minion a card and eal ane minion
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 1.3522
# Give a minion +1/+1.<b>Battlecry:</b> Give a random minion in your han
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 1.2012
# 0//b> <b>Deathrattle:</b> Summon a 1/1 Soppen to your hand.<b>Battlecr
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 1.0888
# ponent (1) less a minions a damage to a minions and a damage to a mini
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.9862
# f or each minion in your hand.<b>Battlecry:</b> Deal 2 damage to a min
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.9128
# weat the end of your turn, deal 2 damage to a minion. If you cave a mi
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.8465
# ">Deal $3 damage to a minion. If it your hand into your hand.<b>Battle
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.7926
# n you cant a spell, gain +1/+1.<b>Battlecry::</b> If you control a min
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.7449
# f you have a minion that died this game.[x]<b>Battlecry:</b> Deal $5 d
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.7059
# 8/b> and <b>Divine Shield</b>.<b>Battlecry:</b> If your deck has no du
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.6631
# Attack.<b>Battlecry:</b> Deal 2 damage to all minions.<b>Battlecry:</b
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.6347
# I the battlefield.<b>Battlecry:</b> Deal 2 damage to a random enemy mi
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.6027
# > Deal 1 damage.<b>Battlecry:</b> Deal 1 damage to all enemy minions.<
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.5749
# :</b> Give a random friendly minion to your hand.<b>Battlecry:</b> Giv
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.5480
# 3/+1.<b>Battlecry:</b> Deal 2 damage to all other minions.<b>Battlecry
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.5261
# ponent's class).</i><b>Battlecry:</b> Deal 1 damage to a random enemy.
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.5001
# s to your hand.<b>Battlecry:</b> Destroy a minion with <b>Taunt</b>.<b
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.4807
# % cards of your deck.<b>Battlecry:</b> Destroy a minion with 3 or less
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.4622
# random minion in your hand +1/+1.<b>Battlecry:</b> If you have a Beast
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.4433
# 2/+1.<b>Battlecry:</b> Deal 3 damage to a random enemy minion.<b>Battl
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.4245
#  the endmy hero.<b>Secret:</b> When an enemy attacks, summon a random
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.4079
# Kn +1/+1.<b>Battlecry:</b> Give a friendly minion +1 Health.<b>Battlec
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.3923
# Give all minions in your hand +1/+1.<b>Taunt</b>\n<b>Battlecry:</b> Gi
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.3763
# Wer minions have +1 Attack.<b>Battlecry:</b> Give a friendly minion +1
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.3613
# Undom minion from your deck.<b>Battlecry:</b> If your C'Thun has at le
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.3488
# y of it.Destroy a minion with 5 or more Attack.Your Hero Power can't a
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.3356
# </b> Summon a 1/1 Silver Hand Recruits. If your hand is empty, deal 2
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.3232
# Vb>Deathrattle:</b> Summon a random basic Totem.<b>Battlecry:</b> If y
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.3113
# 5 damage to this minion.<b>Deathrattle:</b> Summon a random 1-Cost min
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.3018
# Your hero is <b>Immune</b> while attacking.Double all damaged minions.
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.2907
# % cards of your deck has only even-Cost cards, deal 2 damage.<b>Battle
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.2812
# 2/+2.<b>Taunt</b>\n<b>Battlecry:</b> Deal 3 damage to a random enemy m
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.2697
# ge to all enemy minions.<b>Taunt</b>\n<b>Battlecry:</b> Gain +1 Attack
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.2628
# qive your C'Thun +1/+1 <i>(wherever it is).</i><b>Charge</b>\nHas +6 A
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.2512
# \n <b>Discover</b> a spell. Reduce the Cost of minions in your hand +1
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.2448
# Attack of_your weapon.<b>Deathrattle:</b> Summon a 1/1 Shadowbeast.<b>
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.2378
# Deathrattle:</b> Summon three 1/1 Reploss for your opponent.<b>Battlec
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.2265
# r hand.[x]After this minion\nsurvives damage,\nsummon a random\n2-Cost
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.2226
# </b> Summon two 1/1 Spiders.<b>Taunt</b>\nCan only attack if you have
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.2165
# _ones.<b>Battlecry:</b> Deal damage equal to this minion's Attack.<b>R
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.2111
# ecry:</b> Summon a friendly minion that died this game.[x]<b>Divine Sh
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.2036
# #1 damage to this minion.<b>Taunt</b>\n<b>Deathrattle:</b> Deal 5 dama
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.1985
# Immune</b> this turn.Whenever you summon a 1-Health minion that deal 1
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.1927
# Power opponent's class)</i>.Deal $5 damage randomly split among all en
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.1893
# Qreze</b> it.Give your opponent a 'Cursed!' card.\nWhile dith, summon
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.1852
# L +1/+1.<b>Battlecry:</b> <b>Silence</b> a_minion.<b>Taunt</b>. <b>Bat
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.1792
# friendly minion +4/+4 and <b>Taunt</b>.Your other Elemental this turns
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.1766
# Deathrattle:</b> Return any spells you cast on this minion with a spel
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.1727
# ! card to your_hand <i>(from your opponent's class)</i>.<b>Battlecry:<
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.1715
# friendly minion loses_<b>Divine Shield</b>, gain +2 Attack.<b>Inspire:
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.1639
# .<b>Battlecry:</b> Give your Demons +1/+1.After a friendly minion dies
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.1623
# Summon a random\n2-Cost minion.Give your minions "<b>Deathrattle:</b>
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.1600
# cry:</b> If you have a Mech, deal 4 damage randomly split among all en
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.1560
# b> Give a <b>Stealthed</b> minion +2/+2.[x]<b>Choose One -</b> Transfo
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.1546
# 5 damage to a minion. If it survives, draw a card.Deal $3 damage.\nIf
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.1527
# -</b> Give a random\n_friendly minion +1/+1.<b>Taunt</b>\n<b>Deathratt
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.1494
# x]<b>Battlecry:</b> If your deck has\nno duplicates, summon a 2/2 Gnol
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.1471
# Power with a better in your hand.<b>Battlecry:</b> Deal 1 damage.<b>Ta
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.1453
# ve a minion's Attack and Health to 3.Deal $3 damage.<b>Stealth</b>\n<b
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.1436
# Immune</b> this turn.Whenever you summon a 1-Health minion. If you hav
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.1412
# "<b>Battlecry:</b> Transform all\n1-Cost cards in your deck.\nDraw a c
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.1391
# Knion in each deck. If yours costs more, restore 7 Health to your_hero
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.1374
# ttle:</b> Summon three 2/2 Runts.<b>Taunt</b>. <b>Battlecry:</b> Gain
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.1353
#  to your hand.<b>Lifesteal</b>Whenever this minion takes damage, summo
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.1363
# Freeze</b> it.Give your opponent a 'Cursed!' card.\nWhile it spells of
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.1320
# ’ther copy into your hand.<b>Deathrattle:</b> Restore 8 Health to the
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.1323
# ’ther characters.<b>Deathrattle:</b> Put a <b>Secret</b> from your dec
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.1330
# Your minions can't be reduced below 1 Health this turn. Draw a card.\n
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.1290
# jacent minions have +2_Attack.At the end of your turn, restore 4 Healt
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.1290
# Vb>Divine Shield</b> and <b>Taunt</b>.Has +2 Attack while your opponen
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.1265
# hat costs_(1).Whenever you gain Armor, give this minion +1/+1.<b>Battl
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.1273
# your opponent's deck and add it to your hand.<b>Choose One -</b> Give
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.1268
# on a 3/3 Bear with <b>Taunt</b>.Force an enemy minion to deal $3 damag
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.1248
# m your deck.Deal $2 damage.\n<b>Combo:</b> Summon a <b>Jade Golem</b>.
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.1251
# #2 damage randomly split among all enemies.Whenever a minion into a ra
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.1245
# s to your hand next turn.Restore #12 Health randomly split among all e
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.1225
# $1 damage to a minion and give it +2_Attack.Gain 1 Mana Crystals. Disc
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.1198
# \n<b>Divine Shield</b>.Draw 2 Demons\nfrom your deck.Deal $4 damage to
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.1215
# Vb>Deathrattle:</b> Summon three\n1/3 Demons with <b>Taunt</b>. If you
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.1205
# 1/+1.Draw 2 cards. <b>Overload:</b> (2)Give a minion "<b>Deathrattle:<
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.1193
# n +2/+1.<b>Battlecry:</b> Destroy a minion with 1 or less Attack until
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.1171
# r hand.Give your hero +3_Attack this turn. Gain 3 Armor.Destroy a mini
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.1171
# One -</b> Transform into a 5/2 minion; or a 2/5 minion.[x]<b>Deathratt
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.1171
# > Deal 1 damage to a random enemy.<b>Battlecry</b>: Add a random Mage
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.1179
# 2 damage to a minion. If it survives, draw a card.Deal $3 damage.\nIf
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.1170
# 0/+>.<b>Secret:</b> After your opponent casts a spell, gain +1/+1.<b>B
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.1165
# +1 Attack while damaged.<b>Taunt</b>\n<b>Divine Shield</b>, <b>Rush</b
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.1149
# Mech.Deal $2 damage to a minion. If it survives, give it <b>Poisonous<
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.1149
# +1 Attack while damaged.<b>Taunt</b>\n<b>Divine Shield</b><b>Battlecry
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.1161
# 9/+>.<b>Secret:</b> When your hero takes damage, deal_that much damage
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.1142
# [x]<b>Battlecry:</b> If your deck has\nno duplicates, the new target.<
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.1123
# Each hat gives +1/+1.Also damages the minions next to whomever it atta
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.1131
# 3/2 Big Bad Wolf.<b>Battlecry:</b> Reveal a minion in each deck. If yo
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.1105
# b> Give your other minions +1 Health.Your <b>Battlecries</b> cand this
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.1136
# inion with 2 or less Attack until end of turn.Give a friendly minion +
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.1115
# #2 damage to this_minion.<b>Taunt</b>\n<b>Battlecry:</b> Deal 2 damage
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.1103
# (1) less for each\ncard you've played from\nanother class.<b>Battlecry
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.1097
# ttlecry:</b> Destroy your opponent's weapon.<b>Deathrattle:</b> Add a
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.1107
# Cost minion.[x]<b>Battlecry:</b> If you control\na minion this game, s
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.1067
# +1 Attack while damaged.<b>Taunt</b>\n<b>Divine Shield</b>.<b>Battlecr
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.1092
# with your opponent.\nGive them a Ransom\nspell to swap backes.<b>Battl
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.1107
# ur opponent's class)</i>.<b>Battlecry:</b> Deal 4 damage.Put a random
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.1093
# 5 with <b>Taunt</b>.<b>Deathrattle:</b> Go dormant. Play 4 <b>Poisonou
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.1081
# ]<b>Battlecry:</b> If you played\nan Elemental last turn,\nadd a rando
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.1089
# jacent minions have +2_Attack.At the end of your turn, restore 4 Healt
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.1079
# 1/+1.[x]<b>Stealth</b>. Whenever this\nattacks, add a random Mech to y
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.1078
# <b>Battlecry:</b> <b>Recruit</b> a minion that costs (4) or less.<b>Ta
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.1074
# with <b>Taunt</b>.<b>Battlecry:</b> Summon a 5/5 Dragon for your oppon
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.1094
# Battlecry:</b> If you're holding a Dragon, gain <b>Taunt</b> and <b>Di
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.1070
# +2 and return it to your hand.<b>Taunt</b>. <b>Battlecry:</b> Gain
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.1063
# One -</b> Transform into a 5/2 minion; or a 2/5 minion.[x]<b>Deathratt
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.1061
# m enemy minion.<b>Battlecry:</b> Summon 1/1 Whelps until you cast this
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.1063
# ponent's class)</i>.Deal $5 damage randomly split among all enemies.Wh
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.1055
# Battlecry:</b> If you're holding a Dragon, gain <b>Taunt</b> and <b>Di
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.1076
# Jat +1/+1.<b>Battlecry:</b> Give a friendly minion +2 Attack.At the en
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.1032
# Qreeze</b> a minion and the minions next to it, and deal $1 damage to
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.1058
# k and Health to 10.<b>Discover</b> a minion that costs (8) or less <i>
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.1040
# e to all enemies.Trigger all <b>Deathrattles</b> on your minions.[x]<b
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.1036
# he start of your turn, restore 3 Health to a damaged friendly characte
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.1043
# k and Health.<b>Battlecry:</b> Lose 1 Health to your hero.Deal $2 dama
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.1035
# Cost minion.[x]<b>Battlecry:</b> If you control\na minion that died th
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.1047
# :</b> Give a friendly minion <b>Windfury</b>.[x]<b>Battlecry:</b> If y
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.1043
# :</b> Give a friendly Mech +4 Health.Whenever a friendly minion is hea
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.1036
# qiel a minion +1/+2.Throw your weapon at a minion. It deals and and pl
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.1033
# :</b> Give a friendly Mech +4 Health.Whenever a friendly minion_dies w
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.1017
# damage.Gain 5 Armor.\nDraw a card.Copy the lowest Cost minion.<b>Battl
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.1023
# ttlecry:</b> Give a friendly Beast +3 Health.<b>Battlecry:</b> Swap st
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.1035
# $1 damage to a minion and give it +2_Attack.Gain 1 Mana Crystal. <b>Wi
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.1014
# /b> Discard two random cards.<b>Battlecry:</b> If you're holding a Dra
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.1016
# Nero. Restore #3 Health to_your hero.Give a minion +2/+6 and <b>Taunt<
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.1017
# damage.\nGain 3 Armor.Shuffle 3 Ambushes into your opponent's deck.Sum
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.1016
# "<b>Secret:</b> When your hero is attacked, deal $2 damage to all enem
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.1004
# Nerover a minion with 3_or less Attack.Destroy a friendly minion and d
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.1015
# ge to all enemy minions. Draw_a card.Draw a card. That card in your ha
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.1014
# ttlecry:</b> Give a friendly Beast +3 Health.<b>Battlecry:</b> Choose
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.1005
# lecry:</b> Restore 4 Health to each hero.After you play a minion, summ
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.1006
# ur hand.<b>Battlecry:</b> Your opponent's Hero Power costs (1).<b>Batt
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.1007
# -$6 damage. <b>Overload:</b> (1)Deal $8 damage to a minion.Summon thre
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.1013
# Restore 6 Health.\n<b>Overload:</b> (1)Both players have\n<b>Rush</b>.
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.1003
# Treants to replace them.Transform a minion\ninto a 1/1 Sheep.Deal $2 d
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0984
# +2/+2.At the start of your turn, if you have at least 3 Mech, add a co
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.1008
# Power becomes 'Give a Beast +2/+2.'Restore #6 Health to a minion and y
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0986
# on a 3/3 Bear with <b>Taunt</b>.Force an enemy minion to deals this tu
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0999
# Battlecry:</b> If you're holding a Dragon, gain <b>Taunt</b> and <b>Di
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0993
# m your deck.Deal $2 damage.\n<b>Combo:</b> Summon a <b>Jade Golem</b>.
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0990
# Undom minion from your deck into the battlefield.<b>Battlecry:</b> Giv
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0992
# r hand.Give your hero +3_Attack this turn. Gain 3 Armor.Destroy your w
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0988
# ! card to your hand <i>(from your opponent's class)</i>.<b>Battlecry:<
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0985
# ze</b> it.Choose a minion. Shuffle 3 copies of it into your hand.<b>De
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0984
# 'The First Seal' to your hand.<b>Stealth</b><b>Deathrattle:</b> Add a
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0978
# ttlecry:</b> Give a friendly Beast +3 Health.<b>Battlecry:</b> Swap st
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0983
# Nerover</b> a Mana Crystal.<b>Deathrattle:</b> Summon a 3/5 Finkenan.D
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0977
# k and Health to 10.<b>Discover</b> a minion that costs (8) or more.<b>
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0979
# Qre:</b> Summon a 1/1 Silver Hand Recruits. Equip a 5/come.Destroy a m
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.1001
# nion from your hand.Your hero can't be targeted by spells or Hero Powe
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0984
# 5 with <b>Taunt</b>.<b>Deathrattle:</b> Go dormant. Play 4 4 4 4 4 4 u
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0978
# Kon a 3/3 Bear with <b>Taunt</b>.Force an enemy minion to your opponen
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0992
# Nerover</b> a Mana Crystals.<b>Deathrattle:</b> Summon a 5/5 Devilsaur
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0982
# .<b>Battlecry:</b> Give your opponent 2 Bananas.[x]<b>Battlecry:</b> C
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0966
# Deathrattle:</b> Put a <b>Secret</b> from your deck into the battlefie
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0972
# ttlecry:</b> Give a minion -2_Attack this turn.<b>Freeze</b> an enemy.
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0965
# /b> Discard two random cards.<b>Battlecry:</b> Summon 2 copy of it.<b>
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0965
# cry:</b> <b>Adapt</b> a friendly_Beast.<b>Battlecry:</b> Summon a 2/1_
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0984
# ).</i>If you control two of these\nat the end of your turn, summon a 1
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0963
# -$6 damage. <b>Overload:</b> (2)Deal $8 damage to a minion. If it’s a
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0972
# #2 damage to_a character. If that kills it, summon a random basic_Tote
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0960
# Treants to replace them.Transform a minion\ninto a 1/1 Sheep.Deal $2 d
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0945
# wer becomes 'Deal 2 damage'. If already in Shadowform: 3 deal 3 damage
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0970
# r hero is <b>Immune</b> this turn.After you summon a minion, give it +
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0959
# Health to your hero.Return a friendly minion to your hand.<b>Battlecry
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0957
# Health to your hero.Return a friendly minion to your hand.<b>Battlecry
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0971
# on a 3/3_Whelp.At the end of your turn, summon a 1/1 Scarab with <b>Ta
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0953
# 'The Storm Guardian' into your deck.<b>Battlecry:</b> If you're holdin
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0948
# ]<b>Battlecry:</b> If your deck has\nno duplicates, the newu target mi
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0960
# \n<b>Battlecry:</b> Restore 2 Health to your hero.Whenever this minion
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0947
# ).</i>If you control two of these\nat the end of your turn, give anoth
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0954
# Jat costs (4) or less.Destroy all minions and summon 2/2 Treants.Spend
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0959
# ).[x]<b>Battlecry:</b> Deal 2 damage to\nall other minions.Can't attac
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0953
# </b> Summon two 1/1 Spiders.<b>Taunt</b>\nCan only attack heroes this
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0938
# Summon a random\n2-Cost minion.Give your minions "<b>Deathrattle:</b>
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0953
# "<b>Secret:</b> When your hero is attacked, deal $2 damage to the enem
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0951
# k and Health.<b>Battlecry:</b> Deal 1 damage to all other minions.At t
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0933
# nt</b>\nHas +4 Attack during your opponent’s turn.<b>Battlecry:</b> Dr
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0948
# 2 damage randomly split among all enemies.Whenever a minion attacks yo
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0948
# ve your C'Thun +1/+1 <i>(wherever it is).</i><b>Battlecry:</b> If an e
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0943
# 'The First Seal' to your hand.<b>Stealth</b><b>Deathrattle:</b> Add a
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0933
# with 7 or more Attack.Whenever this minion takes damage, discard a ran
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0941
# r hand.Give your hero +3_Attack this turn. Gain 3 Armor.Destroy your w
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0953
# ge +1</b><b>Battlecry:</b> Choose a basic Totem. Summon it.Alt minions
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0927
# .<b>Battlecry:</b> Give a friendly Beast +2/+2 and <b>Taunt</b>.Has +2
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0935
# \n<b>Battlecry:</b> Restore 2 Health.Your Hero Power can this turn thi
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0944
# Nerover</b> a Mana Crystal.Give a minion +4/+4. <i>(+4 Attack +2 Healt
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0938
# 7</b> Summon two 1/1 Spiders.<b>Taunt</b>\nCan only attack if you have
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0940
# (2) less.[x]Deal $2 damage to\ntwo random enemy\nminions.Your <b>Secre
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0933
# "<b>Secret:</b> When your hero is attacked, deal $2 damage to a minion
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0934
# Immune</b> this turn.Whenever you summon a 1-Health minion.<b>Battlecr
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0937
# x]<b>Battlecry:</b> Shuffle 3\nAmbushes into your deck.\nWhenever you
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0942
# _enemy minion's Attack to 1.<b>Battlecry:</b> Give your opponent 2 Ban
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0933
# Freeze</b> it.Give your opponent a 'Cursed!' card.\nWhile discard and
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0933
# 1/+1.Draw 2 cards. <b>Overload:</b> (2)Give a minion "<b>Deathrattle:<
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0932
# with 7 or more Attack.Whenever this minion takes damage, discard this
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0933
# Battlecry:</b> If your opponent has 15 or less Health, gain +3/+3_and
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0924
# on a 3/3_Whelp.At the end of your turn, summon a 1/1 Scarab with <b>Ta
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0932
# Nero.<b>Deathrattle:</b> Deal 3 damage to a random enemy minion.All mi
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0929
# +1 Attack while damaged.<b>Taunt</b>\n<b>Divine Shield</b><b>Battlecry
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0918
# Your minions can't be reduced below 1 Health this turn. Draw a card.Gi
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0935
# 'The Storm Guardian' into your deck.<b>Battlecry:</b> If you control a
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0922
# 8/b> Summon two 1/1 Spiders.<b>Taunt</b>\nCan only attack if you have
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0915
# Vb>Divine Shield</b>,\n<b>Lifesteal</b>, <b>Windfury</b>.Whenever you
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0915
# Deathrattle:</b> Resummon this minion."Deal $1 damage to a minion. If
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0914
# cry:</b> If you played an_Elemental last turn, draw a card.Whenever yo
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0928
# "<b>Secret:</b> When your hero is attacked, deal $2 damage to all enem
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0931
# Your spells cost (1) less.<b>Battlecry:</b> If you control a\nminion w
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0917
# /b> Discard two random cards.<b>Battlecry:</b> If you're holding a Dra
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0936
# % cards in a turn to revive this minion.[x]<b>Deathrattle:</b> Summon
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0920
# lecry:</b> Replace your starting Hero Power with a better deck.<b>Secr
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0919
# Echo</b><b>Stealth</b><b>Battlecry:</b> Remove\nthe top card of your d
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0912
# friendly minion loses_<b>Divine Shield</b>, gain +2 Attack.[x]<b>Taunt
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0913
# _enemy minion's Attack to 1.<b>Battlecry:</b> Give your opponent 2 Ban
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0930
# #2 damage to a minion. If it survives, draw a card.Deal $3 damage to a
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0919
# 7</b> Summon two 1/1 Raptors.<b>Battlecry:</b> Summon an exact copy of
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0919
# Vb>Divine Shield</b>,\n<b>Lifesteal</b>, <b>Windfury</b>.Whenever this
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0914
# r hand.[x]After this minion\nsurvives damage,\nsummon a random friendl
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0927
# Deathrattle:</b> If it's your\nopponent's turn,\nsummon a random\n1-Co
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0894
# .<b>Battlecry:</b> Give your Demons +1/+1.After a friendly Beast dies,
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0913
# e your C'Thun\n+3/+3 <i>(wherever it is).</i><b>Battlecry:</b> If an e
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0912
# 4 damage\nto a minion.Deal $5 damage to an undamaged characters.<b>Cho
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0909
# ).</i>If you control two of these\nat the end of your turn, give anoth
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0910
# jacent minions have +2_Attack.At the end of your turn, restore 4 Healt
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0908
# Whenever an enemy minion dies, summon a Leper Gnome.<b>Battlecry:</b>
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0907
# Immune</b> this turn.Whenever you summon a 1-Health minion to your han
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0909
# [x]<b>Battlecry:</b> Give a random\nMurloc in your hand +1/+1.<b>Death
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0907
# Vb>Divine Shield</b>,\n<b>Lifesteal</b>, <b>Windfury</b>.Whenever you
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0912
# Each hat gives +1/+1.Also damages the minions next to whomever it atta
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0909
# Nero.<b>Deathrattle:</b> Give a random friendly minion <b>Divine Shiel
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0904
# Mech.<b>Deathrattle:</b> Deal 3 damage to a random enemy minion.All mi
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0906
# "<b>Secret:</b> When your hero is attacked, deal $2 damage to_the enem
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0909
# jacent minions have +2_Attack.At the end of your turn, restore 4 Healt
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0903
# _enemy.<b>Battlecry:</b> Draw a Pirate from your deck.<b>Battlecry:</b
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0902
# Immune</b> this turn.Whenever you summon a 1-Health minion. Restore #4
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0905
# m your deck.Deal $2 damage.\n<b>Combo:</b> Summon a <b>Jade Golem</b>.
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0907
# on a 3/3_Whelp.At the end of your turn, summon a 1/1 Scarab.Awtarn thi
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0904
# b> Give a <b>Stealthed</b> minion +2/+2.[x]<b>Choose One -</b> Gain 2_
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0911
# Jattlecry:</b> If you're holding a Dragon, gain +1/+1.<b>Battlecry:</b
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0912
# Health to your hero.Return a friendly minion to your hand.<b>Discover<
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0898
# nt</b>.Your other minions have\n<b>Rush</b>.<b>Battlecry</b> and <b>De
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0904
# nion for your opponent.Whenever you play a card, summon a random\n6-Co
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0906
# Summon a random\n2-Cost minion.Give your minions "<b>Deathrattle:</b>
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0890
# 4 damage\nto a minion.Deal $5 damage to an undamaged characters.<b>Cho
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0890
# e to ALL characters.[x]<b>Taunt</b>\nWhenever this minion\nsurvives da
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0900
# 7</b> Summon two 1/1 Spiders.<b>Taunt</b>\nCan only attack if you have
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0891
# 3/2 Big Bad Wolf.<b>Battlecry:</b> Reveal a minion in each deck. If yo
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0900
# "<b>Secret:</b> When your hero is attacked, deal $2 damage to the enem
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0894
# ve your C'Thun +1/+1 <i>(wherever it is).</i><b>Battlecry:</b> If an e
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0890
# Qre:</b> Gain +1/+1 for each other card you've played this turn.<b>Spe
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0901
# ge +1</b><b>Battlecry:</b> Choose a basic Totem. Summon it.Add a rando
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0897
# 5 with <b>Taunt</b>.<b>Deathrattle:</b> Go dormant. Play 4 Health.<b>B
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0892
# Vb>Divine Shield</b> and <b>Taunt</b>.Has +2 Attack while your opponen
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0895
# nt</b>.Transform your Mana Crystals into 2/2 minions. Recover #1/1 car
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0886
# Mecr.<b>Spell Damage +2</b><b>Battlecry:</b> Give a random friendly mi
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0890
# 4 cards in a turn to revive this minion.[x]<b>Deathrattle:</b> Shuffle
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0896
# Health to your hero.Return a friendly minion to your hand.<b>Battlecry
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0902
# nion in each deck. If your costs more, restore 7 Health to your_hero.<
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0884
# ur opponent's class)</i>.<b>Battlecry:</b> Deal 4 damage.Put a random
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0901
# 2 damage to this_minion.<b>Taunt</b>\n<b>Battlecry:</b> Deal 2 damage
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0887
# b> Give a <b>Stealthed</b> minion +2/+2.[x]<b>Choose One -</b> Gain 2_
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0892
# .<b>Battlecry:</b> Give your opponent 2 Bananas.[x]<b>Battlecry:</b> D
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0889
# r hand.Give your hero +3_Attack this turn. Gain 3 Armor.Destroy your w
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0900
# Kon a 3/3 Bear with <b>Taunt</b>.Force an enemy minion to dama Cost.<b
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0885
# Health for each enemy minion.<b>Inspire:</b> Gain <b>Spell Damage +1</
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0885
# Summon a random\n2-Cost minion.Give your minions "<b>Deathrattle:</b>
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0889
# jacent minions have +2_Attack.At the end of your turn, restore 4 Healt
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0886
# ’s empty, gain +3/+3.[x]<b>Battlecry:</b> Gain <b>Taunt</b>.At the end
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0899
# Jat costs (4) or less.Destroy all minions and summon 2/2 Treant."Deal
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0893
# her Murlocs have +2 Attack.<b>Battlecry:</b> If you're holding a Drago
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0891
# 'The Storm Guardian' into your deck.<b>Battlecry:</b> If you're holdin
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0892
# 6/b>\n<b>Battlecry:</b> Summon a copy of this minion.<b>Inspire:</b> R
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0880
# \n<b>Battlecry:</b> Destroy your Totems. Gain +2/+2 for each Shield lo
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0884
# Attack of_your weapon.<b>Deathrattle:</b> At the end of your turn, giv
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0888
# lecry:</b> Replace your starting Hero Power with a better minions.<b>B
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0884
# 1/+1.Your other Murlocs have +1 Attack.<b>Battlecry:</b> Destroy all\n
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0889
# Summon a random\n2-Cost minion.Give your minions "<b>Deathrattle:</b>
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0882
# 4 cards in a turn to revive this minion.[x]<b>Deathrattle:</b> Summon
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0877
# friendly Murloc +1/+1.Whenever a friendly Beast dies, gain +1/+1.<b>Ba
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0885
# qiel your hand.<b>Battlecry:</b> Your opponent's Hero Power costs (1).
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0879
# b> Give a <b>Stealthed</b> minion +2/+2.[x]<b>Choose One -</b> Transfo
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0882
# Vb>Divine Shield</b> and <b>Taunt</b>.Has +2 Attack while your opponen
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0878
# with your opponent.\nGive them a Ransom\nspell to swap bach und. If co
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0870
# ze</b> it.Choose a minion. Shuffle 3 copies of it into your hand.<b>Ba
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0881
# jacent minions have +2_Attack.At the end of your turn, restore 4 Healt
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0876
# b> Give a <b>Stealthed</b> minion +2/+2.[x]<b>Choose One -</b> Gain 2_
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0881
# Give your Totems +2_Health.Deal $2 damage to a minion. <b>Combo:</b> A
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0872
# 7</b> Summon two 2/2 Hyenas.At the start of your turn, dombaa the Atta
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0882
# ze</b> a random enemy.<b>Battlecry:</b> Deal damage equal to this mini
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0875
# Battlecry:</b> If you're holding any cards from another class in your
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0868
# #2 damage to the enemy_hero.Whenever a character is healed, give your\
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0878
# ]<b>Battlecry:</b> If your deck has\nno duplicates, the next player a
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0873
# attlecry:</b> Give both players the power to ROCK! (with a random card
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0873
# Immune</b> this turn.Whenever you summon a 1-Health minion. <b>Combo:<
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0881
# _enemy.<b>Battlecry:</b> Draw a Pirate from your deck.<b>Battlecry:</b
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0870
# 6</b> Summon a 4/2 Elemental.[x]After your hero attacks,\nsummon a 2/2
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0870
# "<b>Secret:</b> When your hero is attacked, deal $2 damage to all othe
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0879
# ]<b>Battlecry:</b> If you played\nan Elemental last turn,\nadd a rando
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0876
# 3/2 Big Bad Wolf.<b>Battlecry:</b> Reveal a minion in each deck. If yo
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0876
# Deal $4 damage.\nDiscard a random card.Each time you play this turn co
#
# Epoch 1/1
# ...
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0788
# your opponent's hand into your hand.Summon two 0/2 minions with <b>Dea
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0793
# b> Give a <b>Stealthed</b> minion +2/+2.[x]<b>Choose One -</b> Transfo
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0791
#  to your hand.<b>Battlecry:</b> Return your other minions have +2/+2.<
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0793
# L your Hero Power.<b>Battlecry:</b> Destroy a minion. Add it your hand
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0795
# Freeze</b> it.Give your opponent a 'Cursed!' card.\nWhile costs (2) mo
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0789
# lecry:</b> Replace your starting Hero Power with a better and Health.
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0782
# Immune</b> this turn.Whenever you summon a 1-Health minion.Your spells
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0791
# Health for each enemy minion.<b>Inspire:</b> Gain <b>Spell Damage +1</
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0800
# Treants to replace them.Transform a minion\ninto a 1/1 Sheep.Deal $2 d
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0791
# ze</b> it.Choose a minion. Shuffle 3 copies of it into your hand.<b>De
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0794
# jacent minions have +2_Attack.At the end of your turn, restore 4 Healt
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0797
# s to upgrade.)</i>Summon one 5/5 Mithril Golem. <i>(Equip to whele dam
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0792
# _enemy.<b>Battlecry:</b> Draw a Pirate from your deck.<b>Battlecry:</b
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0796
# wer becomes 'Deal 2 damage'. If already in Shadowform: 3 damage\nto a
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0789
# Freeze</b> it.Give your opponent a 'Cursed!' card.\nWhile costs (1) le
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0799
# \n<b>Battlecry:</b> Restore 2 Health.Your Hero Power can to your hand.
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0798
# -$6 damage. <b>Overload:</b> (1)Deal $8 damage to a minion. Summon thr
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0793
# damage to a minion. This spell gets double bonus from <b>Secret</b> in
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0779
# 0 Attack, gain 10 Armor.<b>Battlecry:</b> Shuffle a copy of your hand
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0791
# ge to a minion.  If it's a friendly Demon, give it +5/+5 instead.Give
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0789
# ve your C'Thun +1/+1 <i>(wherever it is).</i><b>Battlecry:</b> If an e
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0795
# ; or a 2/4 with <b>Taunt</b>.<b>Battlecry:</b> If your deck has no dup
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0783
# 'The First Seal' to your hand.<b>Stealth</b><b>Deathrattle:</b> Shuffl
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0788
# Deathrattle:</b> If it's your\nopponent's turn,\nsummon a random minio
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0793
# _enemy.<b>Battlecry:</b> Draw a Pirate from your deck.<b>Battlecry:</b
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0797
# % cast a spell, summon a random\n2-Cost minion.Whenever you cast a spe
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0796
# 7</b> If this minion +1/+1.<b>Taunt</b>Whenever you play a 1-Attack, g
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0796
# 3 Attack.Deal $3 damage to a minion. If that kills it, add a random ca
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0786
# \n<b>Battlecry:</b> Restore 2 Health.Your Hero Power can takes damage
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0796
# 'The Storm Guardian' into your deck.<b>Battlecry:</b> If you're holdin
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0793
# Nerover</b> a card.\nGain 3 Armor.<b>Battlecry:</b> Choose a friendly
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0791
# ponent's class)</i>.Deal $5 damage randomly split among all enemies.Wh
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0788
# Vb>Battlecry:</b> If an enemy minion has <b>Taunt</b>, gain +1 Durabil
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0803
# 8/b> Summon two 1/1 Spiders.<b>Taunt</b>\nCan only attack if your hero
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0800
# Qre:</b> Gain +1 Health.<b>Battlecry:</b> <b>Freeze</b> an_enemy.<b>Ta
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0793
# lecry:</b> Restore 4 Health to each hero.After you play a minion, summ
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0793
# .<b>Battlecry:</b> Give your opponent 2 Bananas.[x]<b>Battlecry:</b> D
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0792
# cry:</b> If you're holding a Dragon, gain +1 Attack and <b>Taunt</b>.<
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0789
# +1; or Summon a 3/2 Panther.<b>Discover</b> a spell. Reduce the Cost o
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0789
# Deathrattle:</b> Resummon this minion."Deal $1 damage to a minion. If
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0800
# m enemy.<b>Battlecry:</b> <b>Silence</b> a Demon.<b>Taunt</b>. <b>Over
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0788
# henever this minion takes damage, double its Attack.<b>Deathrattle:</b
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0786
# in +1/+1 for each other card you've played this turn.<b>Spell Damage +
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0794
# ve your C'Thun +1/+1 <i>(wherever it is).</i><b>Battlecry:</b> If an e
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0792
# Mech Dimabellyes<b>\n<b>Discover</b> a card."<b>Battlecry:</b> Cast a
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0792
# Treants to replace them.Transform a minion\ninto a 1/1 Sheep.Deal $2 d
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0793
# > Deal 6 damage to a Dragon.<b>Taunt</b>\n<b>Overload:</b> (1)Both pla
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0797
#  to your hand.<b>Battlecry:</b> Return your other minions have\n<b>Rus
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0797
# \n<b>Battlecry:</b> Restore 2 Health.Your Hero Power can the end of yo
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0792
# #2 damage to a minion. If it survives, summon a 2/2 Slime.<b>Deathratt
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0794
# Your spells cost (1) less.<b>Battlecry:</b> If you control a\nminion,
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0791
# > Deal 6 damage to a Dragon.<b>Taunt</b>\n<b>Overload:</b> (1)Both pla
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0796
# k and Health.<b>Battlecry:</b> Deal 1 damage to all other minions.<b>C
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0792
# nion in your hand.[x]Draw three 1-Cost\nminions from your deck.Wheneve
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0787
# Each hat gives +1/+1.Also damages the minions next to whomever it atta
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0788
# ’s a minion, restore 2 Health to your hero.Whenever you draw a card, p
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0785
# Freeze</b> it.Give your opponent a 'Cursed!' card.\nWhile you cast a s
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0790
# Whenever an enemy minion dies, summon a Leper Gnome.<b>Battlecry:</b>
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0797
# quip 1 1/3 Attack.<b>Battlecry:</b> Summon a 2/2_Squire.<b>Deathrattle
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0798
# lecry:</b> Replace your starting Hero Power with a better and <b>Freez
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0795
# ze</b> it.Choose a minion. Shuffle 3 copies of it into your deck.<b>Ba
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0788
# </b> Summon two 1/1 Spiders.<b>Taunt</b>\nCan only attack if your hero
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0783
#  to your hand.<b>Lifesteal</b>Whenever this minion takes damage, disca
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0791
# 7 Attack.[x]<b>Deathrattle:</b> Summon a\nnumber of 1/1 Manages.[x]<b>
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0792
# cry:</b> Summon two 1/1 Whelps for your opponent.<b>Battlecry:</b> If
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0790
# Battlecry:</b> If you're holding any cards from another class's to you
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0785
# your opponent's deck and add it to your hand.<b>Choose One -</b> Gain
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0793
# damage.Gain 5 Armor.\nDraw a card.Copy the lowest Cost minion from you
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0792
# Paladin, or Warrior\ncard.<b>Battlecry:</b> Give all minions in your h
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0789
# !/b> any character damaged by this minion.Your spells cost (1) more.<b
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0788
# with your opponent.\nGive them a Ransom\nspell to swap back.<b>Battlec
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0794
# Treants to replace them.Transform a minion\ninto a 1/1 Sheep.Deal $2 d
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0792
# Battlecry:</b> If your opponent has 15 or less Health, gain +3/+3_and
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0791
# ).[x]<b>Battlecry:</b> Deal 2 damage to\nall other minions.Can't attac
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0791
# x]<b>Battlecry:</b> The next Murloc\nyou play this turn costs (0).<b>B
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0790
# Summon a random\n2-Cost minion.Give your minions "<b>Deathrattle:</b>
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0789
# cry:</b> If you're holding a Dragon, gain +1 Attack and <b>Taunt</b>.<
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0787
# m your opponent's deck\n_and add it to your hand.<b>Lifesteal</b>.When
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0787
# r hand.[x]After this minion\nsurvives damage,\nsummon a random basic_T
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0794
# andom weapon for each player.[x]<b>Lifesteal</b>\nHas +1 Attack while
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0794
# (2) less if your\nopponent has at least\nthree minions.[x]<b>Deathratt
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0793
# your hand.<b>Taunt</b>. <b>Deathrattle:</b> Deal 2\ndamage to all mini
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0791
# Kon a 3/3_Whelp.At the end of your turn, summon a 1/1 Scarab with <b>T
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0786
# Deathrattle:</b> Resummon this minion."Deal $1 damage to a minion. If
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0783
# , transform it into a Chicken.Has +4 Attack while your opponent's turn
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0790
# L +1/+1.<b>Battlecry:</b> Give a minion +2_Attack this turn.<b>Battlec
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0793
# Jattlecry:</b> If you're holding a Dragon, gain <b>Taunt</b>.<b>Battle
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0787
# damage.[x]<b>Battlecry:</b> <b>Discover</b> a spell.\nRestore #4 Healt
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0782
# ze</b> a random enemy.<b>Battlecry:</b> Deal damage equal to this mini
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0792
# #2 damage to a random enemy minion.<b>Secret:</b> When a minion attack
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0791
# Nerover a Mech, gain +1/+1 and add a <b>Spare Part</b> to your hand.<b
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0803
# </b> Summon two 1/1 Spiders.<b>Taunt</b>\nCan only attack if your hero
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0800
# your opponent's deck and add it to your hand.<b>Choose One -</b> Give
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0790
# on a 3/3_Whelp.At the end of your turn, summon a 1/1 Scarab with <b>Ta
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0789
# your opponent's deck and add it to your hand.<b>Choose One -</b> Give
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0784
# +2/+2.\nIf it's an Elemental, add\na random Elemental\nto your hand.<b
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0796
# b> Give a <b>Stealthed</b> minion +2/+2.[x]<b>Choose One -</b> Transfo
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0792
# e your C'Thun\n+3/+3 <i>(wherever it is).</i><b>Battlecry:</b> If an e
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0792
# [x]<b>Battlecry:</b> If your deck has\nno duplicates, summon a\n2/2 Sl
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0787
# \n<b>Battlecry:</b> Restore 2 Health.Your Hero Power can to your hand.
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0786
# Restore 3_Health.Whenever this minion takes damage, discard this turn,
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0793
# hat costs_(1).Whenever you gain Armor, give this minion +1/+1.<b>Lifes
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0788
# 'The Storm Guardian' into your deck.<b>Battlecry:</b> If you're holdin
#
# Epoch 1/1
# 1545/1545 [==============================] - 5s 3ms/step - loss: 0.0786
# e your C'Thun +2/+2 <i>(wherever it is).</i><b>Battlecry:</b> I

# %%
model.save("models/cardtext_1460epochs.h5")

# %%
cardtext_model = load_model("models/cardtext_1460epochs.h5")
with open('char_mappings_cardtext/ixtochar.pkl', 'rb') as handle:
    cardtext_ix_to_char = pickle.load(handle)

# %%
print(2)
model.load_weights("cardtext_cps/cardtext_checkpoint_500_epoch_1480.hdf5")
# Out:
# 2

# %%
model

# %%
for i in range(10):
    generate_text(cardtext_model, 100, cardtext_ix_to_char)
    print('\n----\n')
# Out:
# 'The First Seal' to your hand.<b>Stealth</b><b>Deathrattle:</b> Deal 2 damage to a non-Mech minion.<
# ----
#
# One -</b> Transform into a 5/2 minion; or a 2/5 minion.[x]<b>Deathrattle:</b> Summon\na random frien
# ----
#
# \n<b>Battlecry:</b> Restore 2 Health.Your Hero Power can takes cast this turn.<b>Inspire:</b> Summon
# ----
#
# 3 Attack.Deal $3 damage to a minion. If that kills it, add a copy of it to your_hand.Draw a card and
# ----
#
# Give your Totems +2_Health.Deal $2 damage to a minion. <b>Overload:</b>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-52-23a621a0ae27> in <module>()
#       1 for i in range(10):
# ----> 2     generate_text(cardtext_model, 100, cardtext_ix_to_char)
#       3     print('\n----\n')
#
# <ipython-input-50-b776c2b27aa7> in generate_text(model, length, ixtochars)
#       9         X[0, i, :][ix[-1]] = 1
#      10         print(ixtochars[ix[-1]], end="")
# ---> 11         ix = np.argmax(model.predict(X[:, :i+1, :])[0], 1)
#      12         hele_tekst.append(ixtochars[ix[-1]])
#      13     return hele_tekst
#
# ~/anaconda3/lib/python3.6/site-packages/keras/models.py in predict(self, x, batch_size, verbose)
#    1004         if not self.built:
#    1005             self.build()
# -> 1006         return self.model.predict(x, batch_size=batch_size, verbose=verbose)
#    1007
#    1008     def predict_on_batch(self, x):
#
# ~/anaconda3/lib/python3.6/site-packages/keras/engine/training.py in predict(self, x, batch_size, verbose, steps)
#    1770         x = _standardize_input_data(x, self._feed_input_names,
#    1771                                     self._feed_input_shapes,
# -> 1772                                     check_batch_axis=False)
#    1773         if self.stateful:
#    1774             if x[0].shape[0] > batch_size and x[0].shape[0] % batch_size != 0:
#
# ~/anaconda3/lib/python3.6/site-packages/keras/engine/training.py in _standardize_input_data(data, names, shapes, check_batch_axis, exception_prefix)
#     140                                  ' dimensions, but got array with shape ' +
#     141                                  str(array.shape))
# --> 142             for j, (dim, ref_dim) in enumerate(zip(array.shape, shapes[i])):
#     143                 if not j and not check_batch_axis:
#     144                     # skip the first axis
#
# KeyboardInterrupt:

# %%
def remake_text(generated_text):
    
    joined = ''.join(generated_text)
    
    return joined

# %%
generated_flavors = [remake_text(generate_text(model, 65)) for i in range(200)]

# %%
import pickle

# %%
with open('generated_flavors', 'rb') as fp:
    genned_flavors = pickle.load(fp)

# %%
genned_flavors
# Out:
# ['blitz, staring at the spider-transportation-machineYeah, I think ',
#  'the Gnomish World Enlarger, gnomes are wary of size-changing inve',
#  "ther doesn't go on a ditch? What is a defendien fish, both explos",
#  ' in it.  He is definitely going to get his hearing checked.Also i',
#  ' smiting now and again.This card makes something really damp.  Oh',
#  ' a buncha totems together.Still angry that the Gadgetzan Rager Cl',
#  "  It's pretty insensitive.Also does weddings.The Grand Tournament",
#  'THE TOULE BOOM!  WARNING THE FOON THE FOOD ME THE COSE!Frosty the',
#  " of kodos or windserpents, but they'll eat pretty much anything. ",
#  "ow with 100% more blast!You'd think you'd be able to control your",
#  "  at's a spirite being when they make to his practers for the tim",
#  'eryone from Doomsayer to Lorewalker Cho seems to ride one.Mannoro',
#  "e less doom.If you won't come to the tar pits, we'll bring them t",
#  'add on your good each offence.  There are even rumon things!"If y',
#  ". You know what I mean? It's ok if you don't.Let's be honest. One",
#  'ULL OF LAVA.I personally prefer some non-ancestral right-the-heck',
#  " Arena, and he averages 12 wins.When he's working out, he binds a",
#  " of kodos or windserpents, but they'll eat pretty much anything. ",
#  "t's okay, he deserved it.It turns out cards DO grow on trees!Harr",
#  'EGHT!Nood are not afreddwed his do it dod a good like a candle.Th',
#  'ords of previous ownerVirtually every member of the pro demon lob',
#  'THE TOULE BOOM!  WARNING THE FOON THE FOOD ME THE COSE!Frosty the',
#  'the Gnomish World Enlarger, gnomes are wary of size-changing inve',
#  "nown throughout the land as the Spooky-nomicon.Brrr, it's cold in",
#  'the promise of an ice cream bar!Sure the extra protection is nice',
#  "T SCRATCH NOSE.For the times when a regular bazooka just isn't en",
#  "  It's pretty insensitive.Also does weddings.The Grand Tournament",
#  "ther doesn't go on a ditch? What is a defendien fish, both explos",
#  'urious.You have chosen poorly.It is true that some druids are sav',
#  'ane who sells windows and shower doors.Makes shockingly good unag',
#  "  a the suce and everyone forgets about him.He's so hot right now",
#  "ost this sign for a chance at a key.It's not his fault…  Someone ",
#  'o the fold feeds out of cheaking sturt into the insoriting.  You ',
#  'old prefer song drop. I think I love it, "Meely\'le rook." - Hamme',
#  'sed to be five Horsemen but one of them left because a job opened',
#  'he same as the previous generation but they slapped the word "upg',
#  'i>is</i> art.Mass production of warbots was halted when it was di',
#  ' a funn gore.  Just conversation."King\'s Attacker" is a lot more ',
#  'ozen is a swarming Handor. And Huffer. And Huffer. And Huffer.Med',
#  ' To make candle. To keep candle. To hear lamentations of candle-t',
#  'ETTY good for Beardo since the population explosion.  And since t',
#  'blitz, staring at the spider-transportation-machineYeah, I think ',
#  ' roll records.PREPARE PARTY SERVOS FOR IMMEDIATE DEPLOYMENT.As a ',
#  "e was younger, he was the town crybaby.Sure, they're ugly, but th",
#  '   Cet of Creaping gire of the Kirin Tor were casting Cubes of Co',
#  "u know, the whole Lich King thing.He's very good at retrieving ar",
#  'et a job henching!He loves his job and would do it for free!  (Bu',
#  'nd Malygos.  And Nekros.Was actually a pretty nice guy before, yo',
#  " Arena, and he averages 12 wins.When he's working out, he binds a",
#  " try Holy Water: Zero.C'mon Molten Giant!!Come to beautiful Ironf",
#  ". You know what I mean? It's ok if you don't.Let's be honest. One",
#  'THE TOULE BOOM!  WARNING THE FOON THE FOOD ME THE COSE!Frosty the',
#  " of kodos or windserpents, but they'll eat pretty much anything. ",
#  ' a buncha totems together.Still angry that the Gadgetzan Rager Cl',
#  "u know, the whole Lich King thing.He's very good at retrieving ar",
#  'sed to be five Horsemen but one of them left because a job opened',
#  ' smiting now and again.This card makes something really damp.  Oh',
#  "e was younger, he was the town crybaby.Sure, they're ugly, but th",
#  'e "The Hobbit" and "Grendel"."ME HAVE GOOD STATS FOR THE COST"You',
#  " of kodos or windserpents, but they'll eat pretty much anything. ",
#  'k up some 10 cost minions? thx"His new shampoo is really working!',
#  " anyways.It's a literal lava lamp!Doesn't like to adapt unless ot",
#  ' a feed on fears of a truetal misunderstood are supposed to go to',
#  'weeks*."He can never take a bath. Ewww.When a Water elemental and',
#  ' a buncha totems together.Still angry that the Gadgetzan Rager Cl',
#  'bolt-shaped scar on your target.If a bright light shines on a pri',
#  " A fellow of infinite jest, of most excellent fancy!Sure, he'll r",
#  ' a buncha totems together.Still angry that the Gadgetzan Rager Cl',
#  'heels."The yetis of Chillwind Point are a source of both inspirat',
#  's a self-reducing prophecy.He loves a good yarn."It\'s an herbivo ',
#  '23“JJJ3JJJ”JJ3\xa0WWzerUThe Frostwolves are sure when the one the su',
#  'ought with rocks.  Now she fights with ROCK!Contains 75% more fib',
#  'EFORE he was bitten by that ghoul.Astral kitty litter is surprisi',
#  '3333\xa0“(JJ((((((JJJ“WEANG OT deal long of a from him."It\'s someone',
#  'oonfire, and never stop." - How to Be a Druid, Chapter 5, Section',
#  'ust nap under these trees. Wait... AAAAAHHH!" - Blinkfizz, the Un',
#  'l soothe him.  Yeah...  Try that.A popular local alternative to b',
#  'heels."The yetis of Chillwind Point are a source of both inspirat',
#  'sed to be five Horsemen but one of them left because a job opened',
#  't go to school for healing, but we keep losing all the good heale',
#  'the Gnomish World Enlarger, gnomes are wary of size-changing inve',
#  "t's okay, he deserved it.It turns out cards DO grow on trees!Harr",
#  ' a dancer.  Punner of cater".When is just too have are not great ',
#  " defended into first best!  And Muggs.  But it doesn't know you g",
#  ' a bundle of Fel Lotus.Quick! Before I drown! Let me sharpen your',
#  ".Now that's a world champion cheesecake!Three Princes stand befor",
#  'nd Malygos.  And Nekros.Was actually a pretty nice guy before, yo',
#  'oonfire, and never stop." - How to Be a Druid, Chapter 5, Section',
#  'eryone from Doomsayer to Lorewalker Cho seems to ride one.Mannoro',
#  'sed to be five Horsemen but one of them left because a job opened',
#  'ought with rocks.  Now she fights with ROCK!Contains 75% more fib',
#  'bolt-shaped scar on your target.If a bright light shines on a pri',
#  "ther doesn't go on a ditch? What is a defendien fish, both explos",
#  'pedition over control of Alterac Valley.  Every attempt at peace-',
#  '  and the put to storicaly and soul things on fire.  You might wa',
#  'ust nap under these trees. Wait... AAAAAHHH!" - Blinkfizz, the Un',
#  " people get better.  That's why she hurts them in the first place",
#  ' a buncha totems together.Still angry that the Gadgetzan Rager Cl',
#  ' roll records.PREPARE PARTY SERVOS FOR IMMEDIATE DEPLOYMENT.As a ',
#  'old prefer song drop. I think I love it, "Meely\'le rook." - Hamme',
#  ' in it.  He is definitely going to get his hearing checked.Also i',
#  "  at's a spirite being when they make to his practers for the tim",
#  "e was younger, he was the town crybaby.Sure, they're ugly, but th",
#  "the Marshal - it's the law!Her favorite mixture is cola and lime.",
#  " Arena, and he averages 12 wins.When he's working out, he binds a",
#  "  It's pretty insensitive.Also does weddings.The Grand Tournament",
#  'bolt-shaped scar on your target.If a bright light shines on a pri',
#  'ust nap under these trees. Wait... AAAAAHHH!" - Blinkfizz, the Un',
#  ' the dungeon and noticed a slain adventurer. In his final moments',
#  'EGHT!Nood are not afreddwed his do it dod a good like a candle.Th',
#  '   Cet of Creaping gire of the Kirin Tor were casting Cubes of Co',
#  'i>is</i> art.Mass production of warbots was halted when it was di',
#  'l soothe him.  Yeah...  Try that.A popular local alternative to b',
#  'Can’t find any that fit!).When life gives you snow…"Overheat thre',
#  ' the dungeon and noticed a slain adventurer. In his final moments',
#  "e was younger, he was the town crybaby.Sure, they're ugly, but th",
#  'eryone from Doomsayer to Lorewalker Cho seems to ride one.Mannoro',
#  ' smiting now and again.This card makes something really damp.  Oh',
#  'e "The Hobbit" and "Grendel"."ME HAVE GOOD STATS FOR THE COST"You',
#  " Arena, and he averages 12 wins.When he's working out, he binds a",
#  ' a bundle of Fel Lotus.Quick! Before I drown! Let me sharpen your',
#  'SWEATERS! MORE SWEATERS!”They call him "Blackwing" because he\'s a',
#  'ually anymore something?  The Argent was corden and and his first',
#  "u know, the whole Lich King thing.He's very good at retrieving ar",
#  ' a bundle of Fel Lotus.Quick! Before I drown! Let me sharpen your',
#  't go to school for healing, but we keep losing all the good heale',
#  'l soothe him.  Yeah...  Try that.A popular local alternative to b',
#  "uJees takes.He's gotten to himself in starting to have a might on",
#  'ockle for just an everyone else be all "Black Dragonflight, it\'s ',
#  '3333\xa0“(JJ((((((JJJ“WEANG OT deal long of a from him."It\'s someone',
#  ' a feed on fears of a truetal misunderstood are supposed to go to',
#  ' a bundle of Fel Lotus.Quick! Before I drown! Let me sharpen your',
#  'nd Malygos.  And Nekros.Was actually a pretty nice guy before, yo',
#  'bolt-shaped scar on your target.If a bright light shines on a pri',
#  'trike being worse than Fireball.This would be real handy if your ',
#  'weeks*."He can never take a bath. Ewww.When a Water elemental and',
#  'SWEATERS! MORE SWEATERS!”They call him "Blackwing" because he\'s a',
#  "  It's pretty insensitive.Also does weddings.The Grand Tournament",
#  "uJees takes.He's gotten to himself in starting to have a might on",
#  "ow with 100% more blast!You'd think you'd be able to control your",
#  '3333\xa0“(JJ((((((JJJ“WEANG OT deal long of a from him."It\'s someone',
#  ' he yelled. But all that came out was a deep grinding sound. He b',
#  "the Marshal - it's the law!Her favorite mixture is cola and lime.",
#  'eryone from Doomsayer to Lorewalker Cho seems to ride one.Mannoro',
#  'i>is</i> art.Mass production of warbots was halted when it was di',
#  'the promise of an ice cream bar!Sure the extra protection is nice',
#  "  at's a spirite being when they make to his practers for the tim",
#  ' he yelled. But all that came out was a deep grinding sound. He b',
#  '  It takes a long time to get blood stains out of leather armor.I',
#  'SWEATERS! MORE SWEATERS!”They call him "Blackwing" because he\'s a',
#  " try Holy Water: Zero.C'mon Molten Giant!!Come to beautiful Ironf",
#  "t's okay, he deserved it.It turns out cards DO grow on trees!Harr",
#  "e was younger, he was the town crybaby.Sure, they're ugly, but th",
#  "ETH, not like curved pirate blades.  That's a different kind of d",
#  'ozen is a swarming Handor. And Huffer. And Huffer. And Huffer.Med',
#  '  and the put to storicaly and soul things on fire.  You might wa',
#  'urious.You have chosen poorly.It is true that some druids are sav',
#  'bolt-shaped scar on your target.If a bright light shines on a pri',
#  ' this thing.A pair of stout dwarves nearly averted the Cataclysm.',
#  "ow with 100% more blast!You'd think you'd be able to control your",
#  " of kodos or windserpents, but they'll eat pretty much anything. ",
#  "  It's pretty insensitive.Also does weddings.The Grand Tournament",
#  '  and the put to storicaly and soul things on fire.  You might wa',
#  'SWEATERS! MORE SWEATERS!”They call him "Blackwing" because he\'s a',
#  ' a feed on fears of a truetal misunderstood are supposed to go to',
#  'he same as the previous generation but they slapped the word "upg',
#  ".Now that's a world champion cheesecake!Three Princes stand befor",
#  'the promise of an ice cream bar!Sure the extra protection is nice',
#  'weeks*."He can never take a bath. Ewww.When a Water elemental and',
#  'EGHT!Nood are not afreddwed his do it dod a good like a candle.Th',
#  ' he yelled. But all that came out was a deep grinding sound. He b',
#  'add on your good each offence.  There are even rumon things!"If y',
#  'OOOOOOOOOOOM!!!!!"Nominated as "Spell Most Likely to Make Your Op',
#  'ually anymore something?  The Argent was corden and and his first',
#  'eryone from Doomsayer to Lorewalker Cho seems to ride one.Mannoro',
#  'oonfire, and never stop." - How to Be a Druid, Chapter 5, Section',
#  'k up some 10 cost minions? thx"His new shampoo is really working!',
#  " people get better.  That's why she hurts them in the first place",
#  'i>is</i> art.Mass production of warbots was halted when it was di',
#  "u know, the whole Lich King thing.He's very good at retrieving ar",
#  'ords of previous ownerVirtually every member of the pro demon lob',
#  "t's okay, he deserved it.It turns out cards DO grow on trees!Harr",
#  'SWEATERS! MORE SWEATERS!”They call him "Blackwing" because he\'s a',
#  ' he yelled. But all that came out was a deep grinding sound. He b',
#  ' this thing.A pair of stout dwarves nearly averted the Cataclysm.',
#  ' he yelled. But all that came out was a deep grinding sound. He b',
#  'heels."The yetis of Chillwind Point are a source of both inspirat',
#  ' a feed on fears of a truetal misunderstood are supposed to go to',
#  '  and the put to storicaly and soul things on fire.  You might wa',
#  'the Gnomish World Enlarger, gnomes are wary of size-changing inve',
#  '  It takes a long time to get blood stains out of leather armor.I',
#  'ought with rocks.  Now she fights with ROCK!Contains 75% more fib',
#  'Can’t find any that fit!).When life gives you snow…"Overheat thre',
#  "e was younger, he was the town crybaby.Sure, they're ugly, but th",
#  "u know, the whole Lich King thing.He's very good at retrieving ar",
#  "  at's a spirite being when they make to his practers for the tim",
#  "T SCRATCH NOSE.For the times when a regular bazooka just isn't en",
#  'ually anymore something?  The Argent was corden and and his first',
#  't staring contests.The Blood Knights get their holy powers from t',
#  "uJees takes.He's gotten to himself in starting to have a might on"]
